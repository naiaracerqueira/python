# %%
import re
import requests

# %%
url = "https://loja.cozinhasitatiaia.com.br" + "/produto/cozinha-itatiaia-bbb-9-pecas-branca-matte.html"

# %%
url
# Out:
# 'https://loja.cozinhasitatiaia.com.br/produto/cozinha-itatiaia-bbb-9-pecas-branca-matte.html'

# %%
re.sub("/produto", "", url)
# Out:
# 'https://loja.cozinhasitatiaia.com.br/cozinha-itatiaia-bbb-9-pecas-branca-matte.html'

# %%
re.sub("/produto", "", "naiara")
# Out:
# 'naiara'

# %%
if not re.match("/catalogsearch", url):
    print('ok')
# Out:
# ok

# %%
url2= "https://loja.cozinhasitatiaia.com.br/cBônusatalogsearch/cozinha-itatiaia-bbb-9-pecas-branca-matte.html"

# %%
if not re.match(".*/catalogsearch/.*", url2):
    print('ok')
else:
    print('TEM')
# Out:
# TEM

# %%
url3 = 'https://loja.cozinhasitatiaia.com.br/itatiaia-no-bbb?fbclid=IwAR1wPHliTuU4_CSpCKDsoMDOj_gzQzRZpMJGgFtnAkfuUwCQUinG4EHW9EA'

# %%
re.sub("\?fbclid.*", "", url3)
# Out:
# 'https://loja.cozinhasitatiaia.com.br/itatiaia-no-bbb'

# %%
url = 'https://www.cozinhasitatiaia.com.br/'

# %%
r = requests.get(url)

# %%
historico = re.findall(r'\d\d\d', str(r.history))

# %%
historico
# Out:
# []

# %%
if len(historico) == 0:
    historico = 0
else:
    historico = int(historico)

# %%
historico
# Out:
# 0

# %%
url = 'https://www.cozinhasitatiaia.com.br/'
url2 = 'https://www.cozinhasitatiaia.com.br/en/gourmet-kitchen-furniture/'

# %%
r = requests.get(url)

historico = re.findall(r'\d\d\d', str(r.history))

# %%
int(historico[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-7714cb781156> in <module>()
# ----> 1 int(historico[0])
#
# IndexError: list index out of range

# %%
if len(historico) == 0:
    historico = 0
else:
    historico = int(re.findall(r'\d\d\d', str(r.history)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-1ad1a59c1fdd> in <module>()
#       2     historico = 0
#       3 else:
# ----> 4     historico = int(re.findall(r'\d\d\d', str(r.history)))
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
historico
# Out:
# 0

# %%
nome = 'nayara'

re.sub("y","i", nome)
# Out:
# 'naiara'

# %%
nome
# Out:
# 'nayara'

# %%
nome = '"nayara,."'

nome.replace(".|\"|,","")
# Out:
# '"nayara,."'

# %%
nome
# Out:
# '"nayara,."'

# %%
nome.replace(",","").replace(".","").replace("\"", "")
# Out:
# 'nayara'

# %%
nome
# Out:
# '"nayara,."'

# %%
nome =
