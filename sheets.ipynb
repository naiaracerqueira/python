# %% [markdown]
# ## ERRADO

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
worksheet = gc.open('Links quebrados do blog').sheet1
data = worksheet.get_all_values()

df = pd.DataFrame(data)
df
# Out:
#        0  ...            6
# 0      #  ...       Status
# 1      1  ...
# 2      2  ...  Funcionando
# 3      3  ...     Corrigir
# 4      4  ...
# ..   ...  ...          ...
# 409  409  ...
# 410  410  ...
# 411  411  ...
# 412  412  ...
# 413  413  ...
#
# [414 rows x 7 columns]

# %% [markdown]
# ## CERTO

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls '/content/drive/My Drive/Colab Notebooks'
# Out:
#  adicionar_linhas.ipynb  'Links quebrados do blog.xlsx'   sheets.ipynb
#  bar_chart_race.ipynb	  lista.ipynb			  sopa_bonita.ipynb
#  datas.ipynb		  MOZÃO.xlsx			  testes.ipynb
#  linkedin		 'requests e re.ipynb'

# %%
# from openpyxl import load_workbook as load
# from openpyxl import Workbook
import openpyxl

wb = openpyxl.load_workbook('/content/drive/My Drive/Colab Notebooks/Links quebrados do blog.xlsx')
ws = wb['Broken link checker']
first_column = ws["D"]

# %%
first_column
# Out:
# (<Cell 'Broken link checker'.D1>,
#  <Cell 'Broken link checker'.D2>,
#  <Cell 'Broken link checker'.D3>,
#  <Cell 'Broken link checker'.D4>,
#  <Cell 'Broken link checker'.D5>,
#  <Cell 'Broken link checker'.D6>,
#  <Cell 'Broken link checker'.D7>,
#  <Cell 'Broken link checker'.D8>,
#  <Cell 'Broken link checker'.D9>,
#  <Cell 'Broken link checker'.D10>,
#  <Cell 'Broken link checker'.D11>,
#  <Cell 'Broken link checker'.D12>,
#  <Cell 'Broken link checker'.D13>,
#  <Cell 'Broken link checker'.D14>,
#  <Cell 'Broken link checker'.D15>,
#  <Cell 'Broken link checker'.D16>,
#  <Cell 'Broken link checker'.D17>,
#  <Cell 'Broken link checker'.D18>,
#  <Cell 'Broken link checker'.D19>,
#  <Cell 'Broken link checker'.D20>,
#  <Cell 'Broken link checker'.D21>,
#  <Cell 'Broken link checker'.D22>,
#  <Cell 'Broken link checker'.D23>,
#  <Cell 'Broken link checker'.D24>,
#  <Cell 'Broken link checker'.D25>,
#  <Cell 'Broken link checker'.D26>,
#  <Cell 'Broken link checker'.D27>,
# ...

# %%
ws.cell(row=200, column=4).hyperlink.target
# Out:
# 'https://blog.psicologiaviva.com.br/adaptacao-em-tempos-de-covid-19/'

# %%
ws.max_row
# Out:
# 414

# %%
lista = []
for i in range(2, ws.max_row+1):
    lista.append(ws.cell(row=i, column=4).hyperlink.target)

# %%
len(lista)
# Out:
# 413

# %%
lista
# Out:
# ['https://blog.psicologiaviva.com.br/',
#  'https://blog.psicologiaviva.com.br/author/contatopsicologiaviva-com-br/',
#  'https://blog.psicologiaviva.com.br/entrando-em-depressao/',
#  'https://blog.psicologiaviva.com.br/entrando-em-depressao/',
#  'https://blog.psicologiaviva.com.br/sindrome-de-burnout/',
#  'https://blog.psicologiaviva.com.br/inteligencia-emocional/',
#  'https://blog.psicologiaviva.com.br/primeira-consulta-com-psicologo/',
#  'https://blog.psicologiaviva.com.br/superar-a-depressao/',
#  'https://blog.psicologiaviva.com.br/questionario-de-ansiedade-e-depressao-2/',
#  'https://blog.psicologiaviva.com.br/entrando-em-depressao/',
#  'https://blog.psicologiaviva.com.br/entrando-em-depressao/',
#  'https://blog.psicologiaviva.com.br/entrando-em-depressao/',
#  'https://blog.psicologiaviva.com.br/entrando-em-depressao/',
#  'https://blog.psicologiaviva.com.br/entrando-em-depressao/',
#  'https://blog.psicologiaviva.com.br/entrando-em-depressao/',
# ...

# %%
df = pd.DataFrame(lista)
df
# Out:
#                                                      0
# 0                  https://blog.psicologiaviva.com.br/
# 1    https://blog.psicologiaviva.com.br/author/cont...
# 2    https://blog.psicologiaviva.com.br/entrando-em...
# 3    https://blog.psicologiaviva.com.br/entrando-em...
# 4    https://blog.psicologiaviva.com.br/sindrome-de...
# ..                                                 ...
# 408  https://blog.psicologiaviva.com.br/alienacao-p...
# 409        https://blog.psicologiaviva.com.br/ser-mae/
# 410  https://blog.psicologiaviva.com.br/evitar-os-c...
# 411       https://blog.psicologiaviva.com.br/caso-toc/
# 412  https://blog.psicologiaviva.com.br/violencia-d...
#
# [413 rows x 1 columns]

# %%
df.to_excel('/content/drive/My Drive/Colab Notebooks/MOZÃO.xlsx')
